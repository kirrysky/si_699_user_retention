# %% [markdown]
# # Error Analysis with Single Feature
#
# - Author: Wen Xin
# - Description: This file is used to do error analysis with every single feature to find whether there is any abnormal.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('error_analysis_data_set.csv')

# %%
columns=list(data.columns)

# %%
columns.remove('voting')
columns.remove('label')

# %%
columns.remove('user_id')

# %%
data['label_2']=np.where((data['voting']==0) & (data['label']==1),"fn",np.nan)

# %%
data['label_2']=np.where((data['voting']==1) & (data['label']==1),"tp",data['label_2'])

# %%
data['label_2']=np.where((data['voting']==0) & (data['label']==0),"tn",data['label_2'])

# %%
data['label_2']=np.where((data['voting']==1) & (data['label']==0),"fp",data['label_2'])

# %%
data['label_2'].unique()
# Out:
# array(['tp', 'fn', 'tn', 'fp'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
columns
# Out:
# ['order_sd',
#  'active_days',
#  'lastgap',
#  'avg_gap',
#  'min_gap',
#  'max_gap',
#  'w1_total_orders',
#  'w2_total_orders',
#  'w3_total_orders',
#  'w4_total_orders',
#  'w5_total_orders',
#  'w6_total_orders',
#  'w7_total_orders',
#  'first_order',
#  'last_order',
#  'accountLength',
#  'overall_time_mean',
#  'update2create_time_mean',
#  'send2update_time_mean',
#  'overall_time_min',
#  'update2create_time_min',
#  'send2update_time_min',
#  'overall_time_max',
#  'update2create_time_max',
#  'send2update_time_max',
#  'intime_rate',
#  'last_coupon_fee',
#  'last_send_type',
#  'order_nums',
#  'city_id',
#  'sex',
#  'age',
#  'login_platform_b',
#  'app_version_b',
#  'age_na',
#  'lastgap_na',
#  'avg_gap_na',
#  'min_gap_na',
#  'max_gap_na',
#  'overall_time_mean_na',
#  'update2create_time_mean_na',
#  'send2update_time_mean_na',
#  'overall_time_min_na',
#  'update2create_time_min_na',
#  'send2update_time_min_na',
#  'overall_time_max_na',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="ticks")

# %%
columns=[
 'last_order',
 'active_days',
 'w7_total_orders',
 'log_total_orders',
 'order_sd',
 'lastgap',
 'avg_gap',
 'w6_total_orders',
 'min_gap',
 'w7_avg_couponworth',
 'order_nums',
 'w7_max_couponworth',
 'w5_total_orders',
 'max_gap',
 'send2update_time_min',
 'update2create_time_min',
 'kitchen_royalty',
 'log_send2update_time_min',
 'app_version_b',
 'w6_max_couponworth',
 'w6_avg_couponworth',
 'w5_avg_couponworth',
 'overall_time_min',
 'w3_total_orders',
 'comment_perc',
 'w4_avg_couponworth',
 'overall_time_max',
 'w1_total_orders',
 'age',
 'accountLength',
 'w3_avg_couponworth',
 'first_order',
 'w2_max_couponworth',
 'update2create_time_mean',
 'w2_avg_couponworth',
 'w1_avg_couponworth',
 'sex',
 'send2update_time_mean',
 'update2create_time_max',
 'last_coupon_fee',
 'log_send2update_time_mean',
 'overall_time_mean',
 'login_platform_b',
 'like_num',
 'staple_price',
 'intime_rate',
 'send2update_time_max',
 'log_overall_time_mean',
 'city_id',
 'log_send2update_time_max']
]=

# %%
for c in columns:
    sns.pairplot(data[[c,'label_2']],hue='label_2',size=5,markers="+")
    plt.savefig(c+'.png')

# %%
sns.pairplot(data[['order_sd','active_days','label_2']],hue='label_2',size=5,markers="+")
